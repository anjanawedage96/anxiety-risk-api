# %% [markdown]
# ### 1. Exploratory Data Analysis
# Load libraries, set constants (random seed, paths), and read the CSV.

# %%
import os, re
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#  Settings 
DATA_PATH = r"C:/Users/USER/anxiety-risk-api/data/anxiety.csv"
PLOT_DIR  = Path("plots/eda")
PLOT_DIR.mkdir(parents=True, exist_ok=True)
RANDOM_STATE = 42
SHOW = True  
sns.set(style="whitegrid", rc={"figure.figsize": (6, 4)})

def safe_name(s: str) -> str:
    return re.sub(r"[^A-Za-z0-9_-]+", "_", str(s))

def save_show(fig, filename: Path):
    """Save figure then show if SHOW=True; finally close to free memory."""
    fig.tight_layout()
    fig.savefig(filename)
    if SHOW:
        plt.show()
    plt.close(fig)

# Load 
df = pd.read_csv(DATA_PATH)

print("Shape:", df.shape)
print("\nDtypes:\n", df.dtypes)
print("\nHead:\n", df.head())

# Missing values
mv = df.isna().sum().to_frame("missing_count")
mv["missing_pct"] = mv["missing_count"] / len(df)
mv.to_csv(PLOT_DIR / "missing_values.csv")
print("\nMissing values saved to plots/eda/missing_values.csv")
# Out:
# Shape: (11000, 19)
#
# Dtypes:
#  Age                                    int64
# Gender                                object
# Occupation                            object
# Sleep Hours                          float64
# Physical Activity (hrs/week)         float64
# Caffeine Intake (mg/day)               int64
# Alcohol Consumption (drinks/week)      int64
# Smoking                               object
# Family History of Anxiety             object
# Stress Level (1-10)                    int64
# Heart Rate (bpm)                       int64
# Breathing Rate (breaths/min)           int64
# Sweating Level (1-5)                   int64
# Dizziness                             object
# Medication                            object
# Therapy Sessions (per month)           int64
# Recent Major Life Event               object
# Diet Quality (1-10)                    int64
# Anxiety Level (1-10)                 float64
# dtype: object
#
# Head:
# ...

# %%
BIN_BOUNDS  = [0, 3, 7, 10]            # (0,3] Low, (3,7] Medium, (7,10] High
BIN_LABELS  = ['Low','Medium','High']
df['anxiety_bin'] = pd.cut(df['Anxiety Level (1-10)'],
                           bins=BIN_BOUNDS, labels=BIN_LABELS,
                           include_lowest=True, right=True)

# %%
BIN_PLOT_DIR = PLOT_DIR / "bins"
BIN_PLOT_DIR.mkdir(parents=True, exist_ok=True)

# 1) Countplot of bins
fig, ax = plt.subplots()
sns.countplot(x=df['anxiety_bin'], order=['Low','Medium','High'], ax=ax)
ax.set_title("Counts of Anxiety Bins")
save_show(fig, BIN_PLOT_DIR / "anxiety_bin_counts.png")

# 2) Numeric features vs bins (boxplots)
for col in num_cols.drop('Anxiety Level (1-10)', errors='ignore'):
    fig, ax = plt.subplots(figsize=(7,4))
    sns.boxplot(x=df['anxiety_bin'], y=df[col],
                order=['Low','Medium','High'], ax=ax)
    ax.set_title(f"{col} by Anxiety Bin")
    plt.xticks(rotation=0)
    save_show(fig, BIN_PLOT_DIR / f"{safe_name(col)}_by_bin_box.png")

    fig, ax = plt.subplots(figsize=(7,4))
    sns.violinplot(x=df['anxiety_bin'], y=df[col],
                   order=['Low','Medium','High'], cut=0, inner='quartile', ax=ax)
    ax.set_title(f"{col} by Anxiety Bin (Violin)")
    save_show(fig, BIN_PLOT_DIR / f"{safe_name(col)}_by_bin_violin.png")

# 3) Categorical features vs bins (stacked proportions)
def stacked_prop_bar(data, cat_col, target_col='anxiety_bin'):
    prop = (data.groupby(cat_col)[target_col]
                .value_counts(normalize=True)
                .rename('prop')
                .reset_index())
    pivot = prop.pivot(index=cat_col, columns=target_col, values='prop')
    pivot = pivot[['Low','Medium','High']]
    pivot.plot(kind='bar', stacked=True, figsize=(7,4), ax=plt.gca())
    plt.ylabel('Proportion')
    plt.title(f"{cat_col} distribution across Anxiety Bins")
    plt.xticks(rotation=45, ha='right')
    plt.legend(title='Bin', bbox_to_anchor=(1.02, 1), loc='upper left')
    plt.tight_layout()

for col in cat_cols:
    fig = plt.figure()
    try:
        stacked_prop_bar(df, col)
        save_show(fig, BIN_PLOT_DIR / f"{safe_name(col)}_stacked_props.png")
    except ValueError:
        plt.close(fig) 

print("Bin-based visuals saved to", BIN_PLOT_DIR)
# Out:
# Bin-based visuals saved to plots\eda\bins
# C:\Users\USER\AppData\Local\Temp\ipykernel_5720\1731621670.py:28: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   prop = (data.groupby(cat_col)[target_col]
